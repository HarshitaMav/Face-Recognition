# %%
import matplotlib.pyplot as plt
import face_recognition
import numpy as np
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
# %matplotlib inline
import cv2

# %%
image = cv2.imread('test1.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
face_locations = face_recognition.face_locations(image)
no_of_faces = len(face_locations)
print('Found {} face(s) in input image.'.format(no_of_faces))

plt.imshow(image)
ax = plt.gca()

for face_location in face_locations:
    top,right,bottom,left = face_location
    x,y,w,h = left,top,right,bottom
    print("A face is located at Top:{},Left:{},Bottom:{},Right:{}".format(x,y,w,h))
    
    rect = Rectangle((x,y),w-x,h-y,fill = False,color = 'red')
    ax.add_patch(rect)
    
plt.show()
# Out:
# Found 6 face(s) in input image.
# A face is located at Top:107,Left:25,Bottom:170,Right:87
# A face is located at Top:197,Left:25,Bottom:259,Right:87
# A face is located at Top:107,Left:115,Bottom:170,Right:177
# A face is located at Top:17,Left:115,Bottom:80,Right:177
# A face is located at Top:197,Left:115,Bottom:259,Right:177
# A face is located at Top:11,Left:25,Bottom:73,Right:87
